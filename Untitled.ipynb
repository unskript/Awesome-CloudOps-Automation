# %%
pip install panel
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting panel
#   Downloading panel-0.14.2-py2.py3-none-any.whl (17.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.1/17.1 MB 19.7 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: bleach in /Users/dougsillars/Library/Python/3.9/lib/python/site-packages (from panel) (5.0.1)
# Collecting typing-extensions
#   Downloading typing_extensions-4.4.0-py3-none-any.whl (26 kB)
# Requirement already satisfied: setuptools>=42 in /Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/site-packages (from panel) (58.0.4)
# Requirement already satisfied: tqdm>=4.48.0 in /Users/dougsillars/Library/Python/3.9/lib/python/site-packages (from panel) (4.64.1)
# Requirement already satisfied: markdown in /Users/dougsillars/Library/Python/3.9/lib/python/site-packages (from panel) (3.4.1)
# Requirement already satisfied: requests in /Users/dougsillars/Library/Python/3.9/lib/python/site-packages (from panel) (2.28.1)
# Collecting param>=1.12.0
#   Downloading param-1.12.3-py2.py3-none-any.whl (87 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 87.0/87.0 kB 9.8 MB/s eta 0:00:00
# Collecting pyviz-comms>=0.7.4
#   Downloading pyviz_comms-2.2.1-py2.py3-none-any.whl (42 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.9/42.9 kB 3.6 MB/s eta 0:00:00
# Collecting bokeh<2.5.0,>=2.4.0
#   Downloading bokeh-2.4.3-py3-none-any.whl (18.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.5/18.5 MB 30.9 MB/s eta 0:00:0000:0100:01
# Collecting pyct>=0.4.4
#   Downloading pyct-0.4.8-py2.py3-none-any.whl (15 kB)
# Requirement already satisfied: numpy>=1.11.3 in /Users/dougsillars/Library/Python/3.9/lib/python/site-packages (from bokeh<2.5.0,>=2.4.0->panel) (1.23.4)
# Requirement already satisfied: tornado>=5.1 in /Users/dougsillars/Library/Python/3.9/lib/python/site-packages (from bokeh<2.5.0,>=2.4.0->panel) (6.2)
# Requirement already satisfied: Jinja2>=2.9 in /Users/dougsillars/Library/Python/3.9/lib/python/site-packages (from bokeh<2.5.0,>=2.4.0->panel) (3.1.2)
# Requirement already satisfied: packaging>=16.8 in /Users/dougsillars/Library/Python/3.9/lib/python/site-packages (from bokeh<2.5.0,>=2.4.0->panel) (21.3)
# Requirement already satisfied: PyYAML>=3.10 in /Users/dougsillars/Library/Python/3.9/lib/python/site-packages (from bokeh<2.5.0,>=2.4.0->panel) (6.0)
# Collecting pillow>=7.1.0
#   Downloading Pillow-9.4.0-cp39-cp39-macosx_11_0_arm64.whl (3.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.0/3.0 MB 23.2 MB/s eta 0:00:00a 0:00:01
# Requirement already satisfied: webencodings in /Users/dougsillars/Library/Python/3.9/lib/python/site-packages (from bleach->panel) (0.5.1)
# Requirement already satisfied: six>=1.9.0 in /Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/site-packages (from bleach->panel) (1.15.0)
# Requirement already satisfied: importlib-metadata>=4.4 in /Users/dougsillars/Library/Python/3.9/lib/python/site-packages (from markdown->panel) (5.0.0)
# Requirement already satisfied: idna<4,>=2.5 in /Users/dougsillars/Library/Python/3.9/lib/python/site-packages (from requests->panel) (3.4)
# Requirement already satisfied: charset-normalizer<3,>=2 in /Users/dougsillars/Library/Python/3.9/lib/python/site-packages (from requests->panel) (2.1.1)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Users/dougsillars/Library/Python/3.9/lib/python/site-packages (from requests->panel) (1.26.12)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/dougsillars/Library/Python/3.9/lib/python/site-packages (from requests->panel) (2022.9.24)
# Requirement already satisfied: zipp>=0.5 in /Users/dougsillars/Library/Python/3.9/lib/python/site-packages (from importlib-metadata>=4.4->markdown->panel) (3.10.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/dougsillars/Library/Python/3.9/lib/python/site-packages (from Jinja2>=2.9->bokeh<2.5.0,>=2.4.0->panel) (2.1.1)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /Users/dougsillars/Library/Python/3.9/lib/python/site-packages (from packaging>=16.8->bokeh<2.5.0,>=2.4.0->panel) (3.0.9)
# Installing collected packages: typing-extensions, pillow, param, pyviz-comms, pyct, bokeh, panel
#   WARNING: The script pyct is installed in '/Users/dougsillars/Library/Python/3.9/bin' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   NOTE: The current PATH contains path(s) starting with `~`, which may not be expanded by all applications.
#   WARNING: The script bokeh is installed in '/Users/dougsillars/Library/Python/3.9/bin' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   NOTE: The current PATH contains path(s) starting with `~`, which may not be expanded by all applications.
#   WARNING: The script panel is installed in '/Users/dougsillars/Library/Python/3.9/bin' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   NOTE: The current PATH contains path(s) starting with `~`, which may not be expanded by all applications.
# Successfully installed bokeh-2.4.3 panel-0.14.2 param-1.12.3 pillow-9.4.0 pyct-0.4.8 pyviz-comms-2.2.1 typing-extensions-4.4.0
#
# [notice] A new release of pip available: 22.3 -> 22.3.1
# [notice] To update, run: /Library/Developer/CommandLineTools/usr/bin/python3 -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd; import numpy as np; import matplotlib.pyplot as plt

csv_file = 'https://raw.githubusercontent.com/holoviz/panel/master/examples/assets/occupancy.csv'
data = pd.read_csv(csv_file, parse_dates=['date'], index_col='date')

data.tail()
# Out:
#                      Temperature  Humidity  Light         CO2  HumidityRatio  \
# date
# 2015-02-10 09:29:00        21.05   36.0975  433.0  787.250000       0.005579
# 2015-02-10 09:29:59        21.05   35.9950  433.0  789.500000       0.005563
# 2015-02-10 09:30:59        21.10   36.0950  433.0  798.500000       0.005596
# 2015-02-10 09:32:00        21.10   36.2600  433.0  820.333333       0.005621
# 2015-02-10 09:33:00        21.10   36.2000  447.0  821.000000       0.005612
#
#                      Occupancy
# date
# 2015-02-10 09:29:00          1
# 2015-02-10 09:29:59          1
# 2015-02-10 09:30:59          1
# 2015-02-10 09:32:00          1
# 2015-02-10 09:33:00          1

# %%
import matplotlib as mpl
mpl.use('agg')

from matplotlib.figure import Figure

def mpl_plot(avg, highlight):
    fig = Figure()
    ax = fig.add_subplot()
    avg.plot(ax=ax)
    if len(highlight): highlight.plot(style='o', ax=ax)
    return fig

def find_outliers(variable='Temperature', window=30, sigma=10, view_fn=mpl_plot):
    avg = data[variable].rolling(window=window).mean()
    residual = data[variable] - avg
    std = residual.rolling(window=window).std()
    outliers = (np.abs(residual) > std * sigma)
    return view_fn(avg, avg[outliers])

# %%
# %matplotlib inline
find_outliers(variable='Temperature', window=20, sigma=10)

# %%
import panel as pn
pn.extension()

window = pn.widgets.IntSlider(name='window', value=30, start=1, end=60)
sigma = pn.widgets.IntSlider(name='sigma', value=10, start=0, end=20)

interactive = pn.bind(find_outliers, window=window, sigma=sigma)
# Out:
# <style>.bk-root, .bk-root .bk:before, .bk-root .bk:after {
#   font-family: var(--jp-ui-font-size1);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--jp-ui-font-color1);
# }
# </style>

# %%
first_app = pn.Column(window, sigma, interactive)

first_app
# Out:
# Column
#     [0] IntSlider(end=60, name='window', start=1, value=30)
#     [1] IntSlider(end=20, name='sigma', value=10)
#     [2] ParamFunction(function)
